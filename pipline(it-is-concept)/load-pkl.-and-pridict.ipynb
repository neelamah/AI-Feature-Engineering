# %%
#Video Link : https://youtu.be/xOccYkgRV4Q


import pickle
import numpy as np


pipe = pickle.load(open('pipe.pkl','rb'))


# Assume user new data input which need to prodict
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

#pridict for new data
pipe.predict(test_input2)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
