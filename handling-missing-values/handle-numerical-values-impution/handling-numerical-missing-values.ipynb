# %% [markdown]
# we can handle  numerical data missing values
#
# 1. mean -> it data distribution is normal
# 2, mean ->  if data is skewed then can use median( having outliers)
#
#
# disadvantage:-
# 1. shape of distribution change
# 2. changes in covarience and corelation
# 3. some more outlier comes.
#
# when to use:-
# 1. when data missing randomly.
# 2. when data missing less than 5%.
#
#
#
# we can apply using pandas and sckit-learn.
# there is one disadvanges of using sckit-learn it change in it make numpy array.
#
#
# after apply what need to check:-
# 1. varience:-we need to check varience(how much deviated from means. varience always shrin when apply mean , median. But it should not shrink to much like orional variance:- 200, after aply mena/mediena variance is= 161)
# 3. distributiom:- distribution of data should not chane to much.
# 4. covarience:- it should not change more.
# 5. corelation:- it should not change more.
# 6. boxplot:- we shlould draw and check boxplot. is there any new outliers added.
